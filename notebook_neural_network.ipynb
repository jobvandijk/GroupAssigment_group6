# %%
from functions_neural_network import main_struct_individual
from functions_neural_network import main_struct_four_class
# Out:
# WARNING:tensorflow:From c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import pandas as pd
# Add the SMILES column to the Train set with descriptors file, otherwise my code breaks and i am not willing to fix that if this also does it

train_descr_df = pd.read_csv("Train set with descriptors.csv")
train_MACCS_df = pd.read_csv("Train set with MACCS keys.csv")

train_descr_df["SMILES"] = train_MACCS_df["SMILES"].copy()

train_descr_df.to_csv("Train set with descriptors.csv", index=False)

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by duplicating lines, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_indiv_duped_descr.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2464 - accuracy: 0.9331 - precision: 0.0000e+00 - recall: 0.0000e+00
# 11/11 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# For model of PKM2  with single input single output:
#
# Balancing weights: {0: 0.5447019867549668, 1: 6.092592592592593}
#
# Accuracy PKM2 :  0.93313068151474
# Val loss PKM2 :  0.2464268058538437
# Precision PKM2 :  0.0
# Recall PKM2 :  0.0
# F1 score PKM2 :  0.0
#
# Number of 0 in PKM2 :  1208  so percentage of 0 in PKM2 :  0.9179331306990881
# Number of 1 in PKM2 :  108  so percentage of 1 in PKM2 :  0.08206686930091185
# Number of predicted 1s for  PKM2 :  0
#
# Number of epochs before early stopping:  126
#
# 11/11 [==============================] - 0s 2ms/step - loss: 0.4099 - accuracy: 0.8571 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# 11/11 [==============================] - 0s 811us/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# For model of ERK2  with single input single output:
#
# Balancing weights: {0: 0.5761821366024519, 1: 3.781609195402299}
#
# Accuracy ERK2 :  0.8571428656578064
# Val loss ERK2 :  0.40987661480903625
# Precision ERK2 :  0.0
# Recall ERK2 :  0.0
# F1 score ERK2 :  0.0
#
# Number of 0 in ERK2 :  1142  so percentage of 0 in ERK2 :  0.8677811550151976
# Number of 1 in ERK2 :  174  so percentage of 1 in ERK2 :  0.13221884498480244
# Number of predicted 1s for  ERK2 :  0
#
# Number of epochs before early stopping:  119
#
#
# Number of untested PKM2 1 predictions:  0
# Number of untested ERK2 1 predictions:  0

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by balancing weights, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_indiv_weights_descr.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 169.4549 - accuracy: 0.9713 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# 9/9 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# For model of PKM2  with single input single output:
#
# Balancing weights: {0: 0.5128676470588235, 1: 19.928571428571427}
#
# Accuracy PKM2 :  0.9713261723518372
# Val loss PKM2 :  169.45486450195312
# Precision PKM2 :  0.0
# Recall PKM2 :  0.0
# F1 score PKM2 :  0.0
#
# Number of 0 in PKM2 :  1088  so percentage of 0 in PKM2 :  0.974910394265233
# Number of 1 in PKM2 :  28  so percentage of 1 in PKM2 :  0.025089605734767026
# Number of predicted 1s for  PKM2 :  0
#
# Number of epochs before early stopping:  45
#
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7990 - accuracy: 0.5627 - precision_3: 0.0513 - recall_3: 0.3529
# 9/9 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.4646385271665918
# Confusion Matrix: None
# For model of ERK2  with single input single output:
#
# Balancing weights: {0: 0.523943661971831, 1: 10.941176470588236}
#
# Accuracy ERK2 :  0.5627239942550659
# Val loss ERK2 :  0.7990129590034485
# Precision ERK2 :  0.05128205195069313
# Recall ERK2 :  0.3529411852359772
# F1 score ERK2 :  0.08955223880597014
#
# Number of 0 in ERK2 :  1065  so percentage of 0 in ERK2 :  0.9543010752688172
# Number of 1 in ERK2 :  51  so percentage of 1 in ERK2 :  0.0456989247311828
# Number of predicted 1s for  ERK2 :  117
#
# Number of epochs before early stopping:  36
#
#
# Number of untested PKM2 1 predictions:  4434
# Number of untested ERK2 1 predictions:  10

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by duping lines, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_indiv_duped_MACCS.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000 - precision_4: 1.0000 - recall_4: 1.0000
# 11/11 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 1.0
# Confusion Matrix: None
# For model of PKM2  with single input single output:
#
# Balancing weights: {0: 0.5447019867549668, 1: 6.092592592592593}
#
# Accuracy PKM2 :  1.0
# Val loss PKM2 :  0.0035231581423431635
# Precision PKM2 :  1.0
# Recall PKM2 :  1.0
# F1 score PKM2 :  1.0
#
# Number of 0 in PKM2 :  1208  so percentage of 0 in PKM2 :  0.9179331306990881
# Number of 1 in PKM2 :  108  so percentage of 1 in PKM2 :  0.08206686930091185
# Number of predicted 1s for  PKM2 :  22
#
# Number of epochs before early stopping:  49
#
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0578 - accuracy: 0.9787 - precision_5: 0.9545 - recall_5: 0.8936
# 11/11 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.9432624113475176
# Confusion Matrix: None
# For model of ERK2  with single input single output:
#
# Balancing weights: {0: 0.5761821366024519, 1: 3.781609195402299}
#
# Accuracy ERK2 :  0.978723406791687
# Val loss ERK2 :  0.05782231688499451
# Precision ERK2 :  0.9545454382896423
# Recall ERK2 :  0.8936170339584351
# F1 score ERK2 :  0.9230769230769231
#
# Number of 0 in ERK2 :  1142  so percentage of 0 in ERK2 :  0.8677811550151976
# Number of 1 in ERK2 :  174  so percentage of 1 in ERK2 :  0.13221884498480244
# Number of predicted 1s for  ERK2 :  44
#
# Number of epochs before early stopping:  32
#
#
# Number of untested PKM2 1 predictions:  22
# Number of untested ERK2 1 predictions:  34

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by balancing weights, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_indiv_weights_MACCS.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1424 - accuracy: 0.9498 - precision_6: 0.2500 - recall_6: 0.3750
# 9/9 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.6708948339483395
# Confusion Matrix: None
# For model of PKM2  with single input single output:
#
# Balancing weights: {0: 0.5128676470588235, 1: 19.928571428571427}
#
# Accuracy PKM2 :  0.9498208165168762
# Val loss PKM2 :  0.14239825308322906
# Precision PKM2 :  0.25
# Recall PKM2 :  0.375
# F1 score PKM2 :  0.3
#
# Number of 0 in PKM2 :  1088  so percentage of 0 in PKM2 :  0.974910394265233
# Number of 1 in PKM2 :  28  so percentage of 1 in PKM2 :  0.025089605734767026
# Number of predicted 1s for  PKM2 :  12
#
# Number of epochs before early stopping:  27
#
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3310 - accuracy: 0.9032 - precision_7: 0.2222 - recall_7: 0.2353
# 9/9 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.590929501571621
# Confusion Matrix: None
# For model of ERK2  with single input single output:
#
# Balancing weights: {0: 0.523943661971831, 1: 10.941176470588236}
#
# Accuracy ERK2 :  0.9032257795333862
# Val loss ERK2 :  0.33097463846206665
# Precision ERK2 :  0.2222222238779068
# Recall ERK2 :  0.23529411852359772
# F1 score ERK2 :  0.22857142857142856
#
# Number of 0 in ERK2 :  1065  so percentage of 0 in ERK2 :  0.9543010752688172
# Number of 1 in ERK2 :  51  so percentage of 1 in ERK2 :  0.0456989247311828
# Number of predicted 1s for  ERK2 :  18
#
# Number of epochs before early stopping:  8
#
#
# Number of untested PKM2 1 predictions:  250
# Number of untested ERK2 1 predictions:  371

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by duping lines, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_4class_duped_descr.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6034 - accuracy: 0.8176 - precision_8: 0.8176 - recall_8: 0.8176
# 11/11 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# Confusion Matrix: None
#
# Balancing weights: {0: 0.31695568400770713, 1: 3.1634615384615383, 2: 1.9352941176470588, 3: 82.25}
#
# Accuracy:  0.8176291584968567
# Val loss:  0.6034134030342102
# Precision:  0.8176291584968567
# Recall:  0.8176291584968567
# F1 score:  0.8176291584968567
#
# Number of 0 in:  1038  so percentage of 0:  0.7887537993920972
# Number of 1 in:  104  so percentage of 1:  0.0790273556231003
# Number of 2 in:  170  so percentage of 2:  0.12917933130699089
# Number of 3 in:  4  so percentage of 3:  0.00303951367781155
#
# Number of predicted 0s for:  329
# Number of predicted 1s for:  0
# Number of predicted 2s for:  0
# Number of predicted 3s for:  0
#
# Number of epochs before early stopping:  160
#
#
# Number of untested PKM2 1 predictions:  4372
# Number of untested ERK2 1 predictions:  0

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by balancing weights, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_4class_weights_descr.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 1.4056 - accuracy: 0.1398 - precision_9: 0.9583 - recall_9: 0.0824
# 9/9 [==============================] - 0s 819us/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Balanced Accuracy: 0.552434456928839
# Confusion Matrix: None
# Confusion Matrix: None
#
# Balancing weights: {0: 0.26878612716763006, 1: 10.333333333333334, 2: 5.58, 3: 279.0}
#
# Accuracy:  0.13978494703769684
# Val loss:  1.4056040048599243
# Precision:  0.9583333134651184
# Recall:  0.08243727684020996
# F1 score:  0.15181518271791852
#
# Number of 0 in:  1038  so percentage of 0:  0.9301075268817204
# Number of 1 in:  27  so percentage of 1:  0.024193548387096774
# Number of 2 in:  50  so percentage of 2:  0.044802867383512544
# Number of 3 in:  1  so percentage of 3:  0.0008960573476702509
#
# Number of predicted 0s for:  28
# Number of predicted 1s for:  0
# Number of predicted 2s for:  251
# Number of predicted 3s for:  0
#
# Number of epochs before early stopping:  27
#
#
# Number of untested PKM2 1 predictions:  0
# Number of untested ERK2 1 predictions:  0

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by duping lines, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_4class_duped_MACCS.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3691 - accuracy: 0.9104 - precision_10: 0.9104 - recall_10: 0.9104
# 9/9 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# Confusion Matrix: None
#
# Balancing weights: {0: 0.26878612716763006, 1: 10.333333333333334, 2: 5.58, 3: 279.0}
#
# Accuracy:  0.9103942513465881
# Val loss:  0.36906471848487854
# Precision:  0.9103942513465881
# Recall:  0.9103942513465881
# F1 score:  0.9103942513465881
#
# Number of 0 in:  1038  so percentage of 0:  0.9301075268817204
# Number of 1 in:  27  so percentage of 1:  0.024193548387096774
# Number of 2 in:  50  so percentage of 2:  0.044802867383512544
# Number of 3 in:  1  so percentage of 3:  0.0008960573476702509
#
# Number of predicted 0s for:  279
# Number of predicted 1s for:  0
# Number of predicted 2s for:  0
# Number of predicted 3s for:  0
#
# Number of epochs before early stopping:  3
#
#
# Number of untested PKM2 1 predictions:  0
# Number of untested ERK2 1 predictions:  0

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by balancing weights, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_4class_duped_MACCS.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4757 - accuracy: 0.8495 - precision_11: 0.8635 - recall_11: 0.8387
# 9/9 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.7297047970479704
# Balanced Accuracy: 0.4681647940074906
# Confusion Matrix: None
# Confusion Matrix: None
#
# Balancing weights: {0: 0.26878612716763006, 1: 10.333333333333334, 2: 5.58, 3: 279.0}
#
# Accuracy:  0.8494623899459839
# Val loss:  0.475711464881897
# Precision:  0.8634686470031738
# Recall:  0.8387096524238586
# F1 score:  0.85090908402569
#
# Number of 0 in:  1038  so percentage of 0:  0.9301075268817204
# Number of 1 in:  27  so percentage of 1:  0.024193548387096774
# Number of 2 in:  50  so percentage of 2:  0.044802867383512544
# Number of 3 in:  1  so percentage of 3:  0.0008960573476702509
#
# Number of predicted 0s for:  250
# Number of predicted 1s for:  12
# Number of predicted 2s for:  14
# Number of predicted 3s for:  3
#
# Number of epochs before early stopping:  37
#
#
# Number of untested PKM2 1 predictions:  289
# Number of untested ERK2 1 predictions:  252
