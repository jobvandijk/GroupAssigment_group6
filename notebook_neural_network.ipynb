# %%
from functions_neural_network import main_struct_individual
from functions_neural_network import main_struct_four_class
# Out:
# WARNING:tensorflow:From c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import pandas as pd
# Add the SMILES column to the train set with descriptors file, otherwise my code breaks and i am not willing to fix that if this also does it

train_descr_df = pd.read_csv("Train set with descriptors.csv")
train_MACCS_df = pd.read_csv("Train set with MACCS keys.csv")

train_descr_df["SMILES"] = train_MACCS_df["SMILES"].copy()

train_descr_df.to_csv("Train set with descriptors.csv", index=False)

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by duplicating lines, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_indiv_duped_descr.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.9362 - precision: 0.0000e+00 - recall: 0.0000e+00
# 11/11 [==============================] - 0s 2ms/step
# descriptor array: (1316, 90)
# untested array: (4460, 123)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[3], line 5
#       2 input_test_file = "Test set with descriptors.csv"
#       3 output_file = "NN_indiv_duped_descr.csv"
# ----> 5 main_struct_individual(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
#       6                         MACCS=False, write_output=False, plot_conf_mat=True)
#
# File c:\Users\20182714\Documents\GitHub\GroupAssigment_group6\functions_neural_network.py:245, in main_struct_individual(input_train_file, input_test_file, output_file, balance_weights, plot_loss, MACCS, write_output, plot_conf_mat)
#     242 pkm2_output = outp_arr[:,0]
#     243 erk2_output = outp_arr[:,1]
# --> 245 predictions_PKM2, untested_predictions_PKM2 = train_model_individual(descr_arr, pkm2_output, untested_descr_arr, mol_name='PKM2', balance_weights=balance_weights[0], plot_loss=True, plot_conf_mat=True)
#     246 predictions_ERK2, untested_predictions_ERK2 = train_model_individual(descr_arr, erk2_output, untested_descr_arr, mol_name='ERK2', balance_weights=balance_weights[0], plot_loss=True, plot_conf_mat=True)
#     248 predictions = np.column_stack((predictions_PKM2, predictions_ERK2))
#
# File c:\Users\20182714\Documents\GitHub\GroupAssigment_group6\functions_neural_network.py:184, in train_model_individual(descriptor_array, outputs_array, untested_data, mol_name, balance_weights, plot_loss, plot_conf_mat)
#     181 print("descriptor array:",descriptor_array.shape)
#     182 print("untested array:", untested_data.shape)
# --> 184 untested_predictions = model.predict(untested_data)
#     185 untested_predictions = np.round(predictions).astype(int)
#     187 if plot_conf_mat == True:
#
# File c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential/dense/Relu defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py", line 18, in <module>
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelapp.py", line 739, in start
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\tornado\platform\asyncio.py", line 205, in start
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py", line 604, in run_forever
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py", line 1909, in _run_once
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\asyncio\events.py", line 80, in _run
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3051, in run_cell
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3106, in _run_cell
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3311, in run_cell_async
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3493, in run_ast_nodes
#
#   File "C:\Users\20182714\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#
#   File "C:\Users\20182714\AppData\Local\Temp\ipykernel_15852\1241586339.py", line 5, in <module>
#
#   File "c:\Users\20182714\Documents\GitHub\GroupAssigment_group6\functions_neural_network.py", line 245, in main_struct_individual
#
#   File "c:\Users\20182714\Documents\GitHub\GroupAssigment_group6\functions_neural_network.py", line 184, in train_model_individual
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py", line 2655, in predict
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py", line 2440, in predict_function
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py", line 2425, in step_function
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py", line 2413, in run_step
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py", line 2381, in predict_step
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py", line 590, in __call__
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer.py", line 1149, in __call__
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 96, in error_handler
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\sequential.py", line 398, in call
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\functional.py", line 515, in call
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\functional.py", line 672, in _run_internal_graph
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer.py", line 1149, in __call__
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 96, in error_handler
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py", line 255, in call
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\activations.py", line 306, in relu
#
#   File "c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py", line 5395, in relu
#
# Matrix size-incompatible: In[0]: [32,123], In[1]: [90,64]
# 	 [[{{node sequential/dense/Relu}}]] [Op:__inference_predict_function_104562]

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by balancing weights, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_indiv_weights_descr.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6901 - accuracy: 0.9749 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# 35/35 [==============================] - 0s 2ms/step
# For model of PKM2  with single input single output:
#
# Balancing weights: {0: 0.5128676470588235, 1: 19.928571428571427}
#
# Accuracy PKM2 :  0.9749103784561157
# Val loss PKM2 :  0.6900762319564819
# Precision PKM2 :  0.0
# Recall PKM2 :  0.0
# F1 score PKM2 :  0.0
#
# Number of 0 in PKM2 :  1088  so percentage of 0 in PKM2 :  0.974910394265233
# Number of 1 in PKM2 :  28  so percentage of 1 in PKM2 :  0.025089605734767026
# Number of predicted 1s for  PKM2 :  0
#
# Number of epochs before early stopping:  13
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6935 - accuracy: 0.0430 - precision_3: 0.0430 - recall_3: 1.0000
# 35/35 [==============================] - 0s 1ms/step
# For model of ERK2  with single input single output:
#
# Balancing weights: {0: 0.523943661971831, 1: 10.941176470588236}
#
# Accuracy ERK2 :  0.04301075264811516
# Val loss ERK2 :  0.6935468316078186
# Precision ERK2 :  0.04301075264811516
# Recall ERK2 :  1.0
# F1 score ERK2 :  0.08740359897172237
#
# Number of 0 in ERK2 :  1065  so percentage of 0 in ERK2 :  0.9543010752688172
# Number of 1 in ERK2 :  51  so percentage of 1 in ERK2 :  0.0456989247311828
# Number of predicted 1s for  ERK2 :  1116
#
# Number of epochs before early stopping:  6
# Balanced Accuracy: 0.5
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# Confusion Matrix: None

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by duping lines, using MACCS keys as input</h3>

# %%
from functions_neural_network import main_struct_four_class
from functions_neural_network import main_struct_individual

input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_indiv_duped_MACCS.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# WARNING:tensorflow:From c:\Users\20182714\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.9970 - precision: 0.9630 - recall: 1.0000
# 42/42 [==============================] - 0s 2ms/step
# For model of PKM2  with single input single output:
#
# Balancing weights: {0: 0.543801652892562, 1: 6.2075471698113205}
#
# Accuracy PKM2 :  0.996960461139679
# Val loss PKM2 :  0.0075964415445923805
# Precision PKM2 :  0.9629629850387573
# Recall PKM2 :  1.0
# F1 score PKM2 :  0.9953051643192489
#
# Number of 0 in PKM2 :  1210  so percentage of 0 in PKM2 :  0.9194528875379939
# Number of 1 in PKM2 :  106  so percentage of 1 in PKM2 :  0.08054711246200608
# Number of predicted 1s for  PKM2 :  107
#
# Number of epochs before early stopping:  50
# 11/11 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9757 - precision_1: 0.8936 - recall_1: 0.9333
# 42/42 [==============================] - 0s 2ms/step
# For model of ERK2  with single input single output:
#
# Balancing weights: {0: 0.5761821366024519, 1: 3.781609195402299}
#
# Accuracy ERK2 :  0.975683867931366
# Val loss ERK2 :  0.12264524400234222
# Precision ERK2 :  0.8936170339584351
# Recall ERK2 :  0.9333333373069763
# F1 score ERK2 :  0.9712643678160919
#
# Number of 0 in ERK2 :  1142  so percentage of 0 in ERK2 :  0.8677811550151976
# Number of 1 in ERK2 :  174  so percentage of 1 in ERK2 :  0.13221884498480244
# Number of predicted 1s for  ERK2 :  174
#
# Number of epochs before early stopping:  25
# Balanced Accuracy: 0.9995867768595041
# Balanced Accuracy: 0.9834430420516537
# Confusion Matrix: None
# Confusion Matrix: None

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by balancing weights, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_indiv_weights_MACCS.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 input_file = "Train set with MACCS keys.csv"
#       2 output_file = "NN_indiv_weights_MACCS.csv"
# ----> 4 main_struct_individual(input_file, output_file, balance_weights=[True,200], plot_loss=False, MACCS=True, write_output=False, plot_conf_mat=True)
#
# File c:\Users\20182714\Documents\GitHub\GroupAssigment_group6\functions_neural_network.py:213, in main_struct_individual(input_file, output_file, balance_weights, plot_loss, MACCS, write_output, plot_conf_mat)
#     210     balanced_df = df
#     212 if MACCS == True:
# --> 213     maccs_keys_string_to_list = [ast.literal_eval(string_list) for string_list in balanced_df["maccs_keys_bitstring"]]
#     214     descr_arr = np.array(maccs_keys_string_to_list)
#     215     outp_arr = np.array(balanced_df[["PKM2_inhibition", "ERK2_inhibition"]].values.tolist())
#
# UnboundLocalError: cannot access local variable 'balanced_df' where it is not associated with a value

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by duping lines, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_4class_duped_descr.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 11/11 [==============================] - 0s 1ms/step - loss: 0.6722 - accuracy: 0.7903 - precision_8: 0.7903 - recall_8: 0.7903
# 42/42 [==============================] - 0s 1ms/step
#
# Balancing weights: {0: 0.31695568400770713, 1: 3.6153846153846154, 2: 1.7978142076502732, 3: 82.25}
#
# Accuracy:  0.7902735471725464
# Val loss:  0.6722299456596375
# Precision:  0.7902735471725464
# Recall:  0.7902735471725464
# F1 score:  0.7902735471725464
#
# Number of 0 in:  1038  so percentage of 0:  0.7887537993920972
# Number of 1 in:  91  so percentage of 1:  0.06914893617021277
# Number of 2 in:  183  so percentage of 2:  0.13905775075987842
# Number of 3 in:  4  so percentage of 3:  0.00303951367781155
#
# Number of predicted 0s for:  1316
# Number of predicted 1s for:  0
# Number of predicted 2s for:  0
# Number of predicted 3s for:  0
#
# Number of epochs before early stopping:  118

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by balancing weights, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_4class_weights_descr.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 1.0473 - accuracy: 0.9104 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00
# 35/35 [==============================] - 0s 1ms/step
#
# Balancing weights: {0: 0.26878612716763006, 1: 10.333333333333334, 2: 5.58, 3: 279.0}
#
# Accuracy:  0.9103942513465881
# Val loss:  1.0473108291625977
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0
#
# Number of 0 in:  1038  so percentage of 0:  0.9301075268817204
# Number of 1 in:  27  so percentage of 1:  0.024193548387096774
# Number of 2 in:  50  so percentage of 2:  0.044802867383512544
# Number of 3 in:  1  so percentage of 3:  0.0008960573476702509
#
# Number of predicted 0s for:  1116
# Number of predicted 1s for:  0
# Number of predicted 2s for:  0
# Number of predicted 3s for:  0
#
# Number of epochs before early stopping:  117

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by duping lines, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_4class_duped_MACCS.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3399 - accuracy: 0.9104 - precision_10: 0.9104 - recall_10: 0.9104
# 35/35 [==============================] - 0s 1ms/step
#
# Balancing weights: {0: 0.26878612716763006, 1: 10.333333333333334, 2: 5.58, 3: 279.0}
#
# Accuracy:  0.9103942513465881
# Val loss:  0.339860200881958
# Precision:  0.9103942513465881
# Recall:  0.9103942513465881
# F1 score:  0.9103942513465881
#
# Number of 0 in:  1038  so percentage of 0:  0.9301075268817204
# Number of 1 in:  27  so percentage of 1:  0.024193548387096774
# Number of 2 in:  50  so percentage of 2:  0.044802867383512544
# Number of 3 in:  1  so percentage of 3:  0.0008960573476702509
#
# Number of predicted 0s for:  1116
# Number of predicted 1s for:  0
# Number of predicted 2s for:  0
# Number of predicted 3s for:  0
#
# Number of epochs before early stopping:  7

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by balancing weights, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_4class_duped_MACCS.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3955 - accuracy: 0.8566 - precision_11: 0.8592 - recall_11: 0.8530
# 35/35 [==============================] - 0s 1ms/step
#
# Balancing weights: {0: 0.26878612716763006, 1: 10.333333333333334, 2: 5.58, 3: 279.0}
#
# Accuracy:  0.856630802154541
# Val loss:  0.3955203592777252
# Precision:  0.8592057824134827
# Recall:  0.8530465960502625
# F1 score:  0.8561151115493025
#
# Number of 0 in:  1038  so percentage of 0:  0.9301075268817204
# Number of 1 in:  27  so percentage of 1:  0.024193548387096774
# Number of 2 in:  50  so percentage of 2:  0.044802867383512544
# Number of 3 in:  1  so percentage of 3:  0.0008960573476702509
#
# Number of predicted 0s for:  1006
# Number of predicted 1s for:  43
# Number of predicted 2s for:  67
# Number of predicted 3s for:  0
#
# Number of epochs before early stopping:  42
