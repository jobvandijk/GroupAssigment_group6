# %%
from functions_neural_network import main_struct_individual
from functions_neural_network import main_struct_four_class

# %%
import pandas as pd
# Add the SMILES column to the Train set with descriptors file, otherwise my code breaks and i am not willing to fix that if this also does it

train_descr_df = pd.read_csv("Train set with descriptors.csv")
train_MACCS_df = pd.read_csv("Train set with MACCS keys.csv")

train_descr_df["SMILES"] = train_MACCS_df["SMILES"].copy()

train_descr_df.to_csv("Train set with descriptors.csv", index=False)

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by duplicating lines, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_indiv_duped_descr.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2764 - accuracy: 0.9210 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00
# 11/11 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# For model of PKM2  with single input single output:
#
# Balancing weights: {0: 0.5433526011560693, 1: 6.266666666666667}
#
# Accuracy PKM2 :  0.9209726452827454
# Val loss PKM2 :  0.27638736367225647
# Precision PKM2 :  0.0
# Recall PKM2 :  0.0
# F1 score PKM2 :  0.0
#
# Number of 0 in PKM2 :  1211  so percentage of 0 in PKM2 :  0.9202127659574468
# Number of 1 in PKM2 :  105  so percentage of 1 in PKM2 :  0.0797872340425532
# Number of predicted 1s for  PKM2 :  0
#
# Number of epochs before early stopping:  142
#
# 11/11 [==============================] - 0s 2ms/step - loss: 0.3554 - accuracy: 0.8875 - precision_13: 0.0000e+00 - recall_13: 0.0000e+00
# 11/11 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# For model of ERK2  with single input single output:
#
# Balancing weights: {0: 0.5771929824561404, 1: 3.7386363636363638}
#
# Accuracy ERK2 :  0.8875380158424377
# Val loss ERK2 :  0.3553619980812073
# Precision ERK2 :  0.0
# Recall ERK2 :  0.0
# F1 score ERK2 :  0.0
#
# Number of 0 in ERK2 :  1140  so percentage of 0 in ERK2 :  0.8662613981762918
# Number of 1 in ERK2 :  176  so percentage of 1 in ERK2 :  0.1337386018237082
# Number of predicted 1s for  ERK2 :  0
#
# Number of epochs before early stopping:  200
#
#
# Number of untested PKM2 1 predictions:  0
# Number of untested ERK2 1 predictions:  0

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by balancing weights, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_indiv_weights_descr.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 31.9275 - accuracy: 0.9677 - precision_14: 0.0000e+00 - recall_14: 0.0000e+00
# 9/9 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# For model of PKM2  with single input single output:
#
# Balancing weights: {0: 0.5128676470588235, 1: 19.928571428571427}
#
# Accuracy PKM2 :  0.9677419066429138
# Val loss PKM2 :  31.927453994750977
# Precision PKM2 :  0.0
# Recall PKM2 :  0.0
# F1 score PKM2 :  0.0
#
# Number of 0 in PKM2 :  1088  so percentage of 0 in PKM2 :  0.974910394265233
# Number of 1 in PKM2 :  28  so percentage of 1 in PKM2 :  0.025089605734767026
# Number of predicted 1s for  PKM2 :  0
#
# Number of epochs before early stopping:  2
#
# 9/9 [==============================] - 0s 2ms/step - loss: 1.0987 - accuracy: 0.1326 - precision_15: 0.0320 - recall_15: 1.0000
# 9/9 [==============================] - 0s 833us/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5535055350553506
# Confusion Matrix: None
# For model of ERK2  with single input single output:
#
# Balancing weights: {0: 0.523943661971831, 1: 10.941176470588236}
#
# Accuracy ERK2 :  0.13261649012565613
# Val loss ERK2 :  1.0986945629119873
# Precision ERK2 :  0.03200000151991844
# Recall ERK2 :  1.0
# F1 score ERK2 :  0.06201550387596899
#
# Number of 0 in ERK2 :  1065  so percentage of 0 in ERK2 :  0.9543010752688172
# Number of 1 in ERK2 :  51  so percentage of 1 in ERK2 :  0.0456989247311828
# Number of predicted 1s for  ERK2 :  250
#
# Number of epochs before early stopping:  78
#
#
# Number of untested PKM2 1 predictions:  0
# Number of untested ERK2 1 predictions:  0

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by duping lines, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_indiv_duped_MACCS.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 0.9970 - precision_16: 0.9655 - recall_16: 1.0000
# 11/11 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 2ms/step
# Balanced Accuracy: 0.9983388704318936
# Confusion Matrix: None
# For model of PKM2  with single input single output:
#
# Balancing weights: {0: 0.544251447477254, 1: 6.149532710280374}
#
# Accuracy PKM2 :  0.996960461139679
# Val loss PKM2 :  0.012967057526111603
# Precision PKM2 :  0.9655172228813171
# Recall PKM2 :  1.0
# F1 score PKM2 :  0.9824561403508771
#
# Number of 0 in PKM2 :  1209  so percentage of 0 in PKM2 :  0.918693009118541
# Number of 1 in PKM2 :  107  so percentage of 1 in PKM2 :  0.08130699088145897
# Number of predicted 1s for  PKM2 :  29
#
# Number of epochs before early stopping:  43
#
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0580 - accuracy: 0.9818 - precision_17: 0.9048 - recall_17: 0.9500
# 11/11 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.9680795847750865
# Confusion Matrix: None
# For model of ERK2  with single input single output:
#
# Balancing weights: {0: 0.5761821366024519, 1: 3.781609195402299}
#
# Accuracy ERK2 :  0.9817629456520081
# Val loss ERK2 :  0.05800531804561615
# Precision ERK2 :  0.9047619104385376
# Recall ERK2 :  0.949999988079071
# F1 score ERK2 :  0.926829268292683
#
# Number of 0 in ERK2 :  1142  so percentage of 0 in ERK2 :  0.8677811550151976
# Number of 1 in ERK2 :  174  so percentage of 1 in ERK2 :  0.13221884498480244
# Number of predicted 1s for  ERK2 :  42
#
# Number of epochs before early stopping:  30
#
#
# Number of untested PKM2 1 predictions:  40
# Number of untested ERK2 1 predictions:  56

# %% [markdown]
# <h3 style="color:red;">Method with individual networks for each output, balanced by balancing weights, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_indiv_weights_MACCS.csv"

main_struct_individual(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2567 - accuracy: 0.8996 - precision_18: 0.2692 - recall_18: 0.4375
# 9/9 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.6826283269961977
# Confusion Matrix: None
# For model of PKM2  with single input single output:
#
# Balancing weights: {0: 0.5128676470588235, 1: 19.928571428571427}
#
# Accuracy PKM2 :  0.8996415734291077
# Val loss PKM2 :  0.2566947042942047
# Precision PKM2 :  0.26923078298568726
# Recall PKM2 :  0.4375
# F1 score PKM2 :  0.3333333333333333
#
# Number of 0 in PKM2 :  1088  so percentage of 0 in PKM2 :  0.974910394265233
# Number of 1 in PKM2 :  28  so percentage of 1 in PKM2 :  0.025089605734767026
# Number of predicted 1s for  PKM2 :  26
#
# Number of epochs before early stopping:  6
#
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8530 - precision_19: 0.0000e+00 - recall_19: 0.0000e+00
# 9/9 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.44569288389513106
# Confusion Matrix: None
# For model of ERK2  with single input single output:
#
# Balancing weights: {0: 0.523943661971831, 1: 10.941176470588236}
#
# Accuracy ERK2 :  0.8530465960502625
# Val loss ERK2 :  0.3827988803386688
# Precision ERK2 :  0.0
# Recall ERK2 :  0.0
# F1 score ERK2 :  0.0
#
# Number of 0 in ERK2 :  1065  so percentage of 0 in ERK2 :  0.9543010752688172
# Number of 1 in ERK2 :  51  so percentage of 1 in ERK2 :  0.0456989247311828
# Number of predicted 1s for  ERK2 :  29
#
# Number of epochs before early stopping:  27
#
#
# Number of untested PKM2 1 predictions:  304
# Number of untested ERK2 1 predictions:  294

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by duping lines, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_4class_duped_descr.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6771 - accuracy: 0.7751 - precision_20: 0.7751 - recall_20: 0.7751
# 11/11 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# Confusion Matrix: None
#
# Balancing weights: {0: 0.31695568400770713, 1: 3.5, 2: 1.8176795580110496, 3: 109.66666666666667}
#
# Accuracy:  0.7750759720802307
# Val loss:  0.6770918965339661
# Precision:  0.7750759720802307
# Recall:  0.7750759720802307
# F1 score:  0.7750759720802307
#
# Number of 0 in:  1038  so percentage of 0:  0.7887537993920972
# Number of 1 in:  94  so percentage of 1:  0.07142857142857142
# Number of 2 in:  181  so percentage of 2:  0.13753799392097266
# Number of 3 in:  3  so percentage of 3:  0.0022796352583586625
#
# Number of predicted 0s for:  329
# Number of predicted 1s for:  0
# Number of predicted 2s for:  0
# Number of predicted 3s for:  0
#
# Number of epochs before early stopping:  200
#
#
# Number of untested PKM2 1 predictions:  0
# Number of untested ERK2 1 predictions:  0

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by balancing weights, using descriptors as input</h3>

# %%
input_file = "Train set with descriptors.csv"
input_test_file = "Test set with descriptors.csv"
output_file = "NN_4class_weights_descr.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=False, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 1.4573 - accuracy: 0.0215 - precision_21: 1.0000 - recall_21: 0.0215
# 9/9 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5112781954887218
# Balanced Accuracy: 0.5113636363636364
# Confusion Matrix: None
# Confusion Matrix: None
#
# Balancing weights: {0: 0.26878612716763006, 1: 10.333333333333334, 2: 5.58, 3: 279.0}
#
# Accuracy:  0.02150537632405758
# Val loss:  1.45732843875885
# Precision:  1.0
# Recall:  0.02150537632405758
# F1 score:  0.04210526311950671
#
# Number of 0 in:  1038  so percentage of 0:  0.9301075268817204
# Number of 1 in:  27  so percentage of 1:  0.024193548387096774
# Number of 2 in:  50  so percentage of 2:  0.044802867383512544
# Number of 3 in:  1  so percentage of 3:  0.0008960573476702509
#
# Number of predicted 0s for:  6
# Number of predicted 1s for:  0
# Number of predicted 2s for:  0
# Number of predicted 3s for:  273
#
# Number of epochs before early stopping:  29
#
#
# Number of untested PKM2 1 predictions:  0
# Number of untested ERK2 1 predictions:  0

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by duping lines, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_4class_duped_MACCS.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[False,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3913 - accuracy: 0.8961 - precision_22: 0.8961 - recall_22: 0.8961
# 9/9 [==============================] - 0s 829us/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.5
# Balanced Accuracy: 0.5
# Confusion Matrix: None
# Confusion Matrix: None
#
# Balancing weights: {0: 0.26878612716763006, 1: 10.333333333333334, 2: 5.58, 3: 279.0}
#
# Accuracy:  0.8960573673248291
# Val loss:  0.3913283348083496
# Precision:  0.8960573673248291
# Recall:  0.8960573673248291
# F1 score:  0.8960573673248291
#
# Number of 0 in:  1038  so percentage of 0:  0.9301075268817204
# Number of 1 in:  27  so percentage of 1:  0.024193548387096774
# Number of 2 in:  50  so percentage of 2:  0.044802867383512544
# Number of 3 in:  1  so percentage of 3:  0.0008960573476702509
#
# Number of predicted 0s for:  279
# Number of predicted 1s for:  0
# Number of predicted 2s for:  0
# Number of predicted 3s for:  0
#
# Number of epochs before early stopping:  3
#
#
# Number of untested PKM2 1 predictions:  0
# Number of untested ERK2 1 predictions:  0

# %% [markdown]
# <h3 style="color:red;">Method with 4 class classification network, balanced by balancing weights, using MACCS keys as input</h3>

# %%
input_file = "Train set with MACCS keys.csv"
input_test_file = "Test set with MACCS keys.csv"
output_file = "NN_4class_duped_MACCS.csv"

main_struct_four_class(input_file, input_test_file, output_file, balance_weights=[True,200], plot_loss=False,
                        MACCS=True, write_output=False, plot_conf_mat=True)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5877 - accuracy: 0.7921 - precision_23: 0.8112 - recall_23: 0.7240
# 9/9 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.7544642857142857
# Balanced Accuracy: 0.49629629629629635
# Confusion Matrix: None
# Confusion Matrix: None
#
# Balancing weights: {0: 0.26878612716763006, 1: 10.333333333333334, 2: 5.58, 3: 279.0}
#
# Accuracy:  0.7921146750450134
# Val loss:  0.5877165198326111
# Precision:  0.8112449645996094
# Recall:  0.7240143418312073
# F1 score:  0.7651515110811479
#
# Number of 0 in:  1038  so percentage of 0:  0.9301075268817204
# Number of 1 in:  27  so percentage of 1:  0.024193548387096774
# Number of 2 in:  50  so percentage of 2:  0.044802867383512544
# Number of 3 in:  1  so percentage of 3:  0.0008960573476702509
#
# Number of predicted 0s for:  226
# Number of predicted 1s for:  20
# Number of predicted 2s for:  32
# Number of predicted 3s for:  1
#
# Number of epochs before early stopping:  29
#
#
# Number of untested PKM2 1 predictions:  300
# Number of untested ERK2 1 predictions:  468
